# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('countries.csv', delimiter=',')

# %%
print(df.shape)
# Out:
# (1704, 3)

# %%
print(df)
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
row, column = df.shape

# %%
print(row)
# Out:
# 1704

# %%
df.head() # Default 5 rows
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
df.tail() # Default 5 rows fow above
# Out:
#        country  year  population
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
df[3:5]
# Out:
#        country  year  population
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
df[3:]
df[0:] # print last row
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
df.iloc[:2]
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934

# %%
df.iloc[2, 1]
# Out:
# 1962

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population'], dtype='object')

# %%
df.columns
# Out:
# Index(['country', 'year', 'population'], dtype='object')

# %%
for index, row in df.iterrows():
    print(index, row)
# Out:
# 0 country       Afghanistan
# year                 1952
# population        8425333
# Name: 0, dtype: object
# 1 country       Afghanistan
# year                 1957
# population        9240934
# Name: 1, dtype: object
# 2 country       Afghanistan
# year                 1962
# population       10267083
# Name: 2, dtype: object
# 3 country       Afghanistan
# year                 1967
# population       11537966
# Name: 3, dtype: object
# 4 country       Afghanistan
# year                 1972
# population       13079460
# Name: 4, dtype: object
# 5 country       Afghanistan
# year                 1977
# population       14880372
# Name: 5, dtype: object
# 6 country       Afghanistan
# year                 1982
# population       12881816
# Name: 6, dtype: object
# 7 country       Afghanistan
# year                 1987
# population       13867957
# Name: 7, dtype: object
# 8 country       Afghanistan
# year                 1992
# population       16317921
# Name: 8, dtype: object
# ...

# %%
df.loc[df["year"] > 1999]
# Out:
#           country  year  population
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 34        Algeria  2002    31287142
# ...           ...   ...         ...
# 1679  Yemen, Rep.  2007    22211743
# 1690       Zambia  2002    10595811
# 1691       Zambia  2007    11746035
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [284 rows x 3 columns]

# %%
df.sort_values('year', ascending=False)
# Out:
#                 country  year  population
# 1703           Zimbabwe  2007    12311143
# 491   Equatorial Guinea  2007      551201
# 515            Ethiopia  2007    76511887
# 527             Finland  2007     5238460
# 539              France  2007    61083916
# ...                 ...   ...         ...
# 1116              Niger  1952     3379468
# 1128            Nigeria  1952    33119096
# 1140             Norway  1952     3327728
# 1152               Oman  1952      507833
# 852              Kuwait  1952      160000
#
# [1704 rows x 3 columns]

# %%
df.to_excel('Countries_test.xlsx')

# %%
df[df['country'].str.contains('India')].min()
# Out:
# country           India
# year               1952
# population    372000000
# dtype: object

# %%
df[df['country'].str.contains('India')].max()
# Out:
# country            India
# year                2007
# population    1110396331
# dtype: object

# %%
india_population = df[df['country'].str.contains('India')]['population']
print(india_population.mean())
# Out:
# 701130739.8333334

# %%
# plt.plot(df.data, df.temperature)
# plt.show()

# %%
us = df[df.country == 'India']
china = df[df.country == 'China']
plt.plot(us.year, us.population/us.population.iloc[0] * 100)
plt.plot(china.year, china.population/
china.population.iloc[0] * 100)
plt.legend(['India', 'China'])
plt.xlabel('Metai')
plt.ylabel('Populiacijos kilimas (pirmi metai = 100 proc.)')
plt.show()

# %%
data = pd.read_csv('countries.csv')
us = df[df.country == 'Afghanistan']
china = df[df.country == 'Zimbabwe']
plt.plot(us.year, us.population/us.population.iloc[0] * 100)
plt.plot(china.year, china.population/
china.population.iloc[0] * 100)
plt.legend(['Afghanistan', 'Zimbabwe'])
plt.xlabel('Metai')
plt.ylabel('Populiacijos kilimas (pirmi metai = 100 proc.)')
plt.show()
